# %%
import pandas as pd

# %%
df = pd.read_csv(r"E:\telecom-egypt-rag\data\evaluation\retrieval_eval_results_v1.csv")

# %%
df.head()
# Out:
#                                                query expected_route  \
# 0                              كود معرفة الرصيد كام؟            NaN
# 1                                   ازاي أعرف رصيدي؟            NaN
# 2                         What is the SIM swap cost?            NaN
# 3  What is the yearly fee for WE Space Mega 3000 GB?            NaN
# 4                What are WE Space recharge add-ons?            NaN
#
#   actual_route  route_match expected_category  category_hit_at_5  \
# 0    retrieval         True          services               True
# 1    retrieval         True          services               True
# 2    retrieval         True               faq               True
# 3    retrieval         True           we_home               True
# 4    retrieval         True           we_home               True
#
#                        expected_contains_any  expected_text_hit_at_5  \
# 0                              550|*550|#550                    True
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   query                       10 non-null     str
#  1   expected_route              1 non-null      str
#  2   actual_route                10 non-null     str
#  3   route_match                 10 non-null     bool
#  4   expected_category           8 non-null      str
#  5   category_hit_at_5           10 non-null     bool
#  6   expected_contains_any       9 non-null      str
#  7   expected_text_hit_at_5      10 non-null     bool
#  8   expected_citation_contains  8 non-null      str
#  9   citation_hit_at_5           10 non-null     bool
#  10  reciprocal_rank             10 non-null     float64
#  11  top_title                   9 non-null      str
#  12  top_category                9 non-null      str
#  13  top_citation_url            9 non-null      str
# ...
